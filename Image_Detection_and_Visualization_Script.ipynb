# %% [markdown]
# <a href="https://colab.research.google.com/github/thegregbeyond/FreeFuse-AI-Calbright-Project/blob/main/Image_Detection_and_Visualization_Script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: (Uncomment to install if needed)
# !pip install pandas opencv-python-headless google-colab -q

import cv2
import pandas as pd
from pathlib import Path
from typing import Optional
from google.colab import drive

# ─── User-Configurable Parameters ─────────────────────────────────────────────
INPUT_CSV     = Path("/content/drive/MyDrive/FreeFuse_Project/Extracted_Stills/YOLOv10/final_annotations.csv")
STILLS_FOLDER = Path("/content/drive/MyDrive/FreeFuse_Project/Extracted_Stills/YOLOv10")
OUTPUT_FOLDER = STILLS_FOLDER / "Visualized_Annotations"

# Drawing settings
BOX_COLOR         = (0, 255, 0)   # BGR
TEXT_COLOR        = (255, 255, 255)
CENTER_DOT_COLOR  = (0, 0, 255)
BOX_THICKNESS     = 2
CENTER_DOT_RADIUS = 5
FONT_FACE         = cv2.FONT_HERSHEY_SIMPLEX
FONT_SCALE        = 0.5
# ────────────────────────────────────────────────────────────────────────────────

def mount_drive():
    print("🔗 Mounting Google Drive…")
    drive.mount("/content/drive", force_remount=True)
    print("✅ Drive mounted.")

def load_annotations(csv_path: Path) -> Optional[pd.DataFrame]:
    if not csv_path.exists():
        print(f"❌ Annotation file not found: {csv_path}")
        return None
    df = pd.read_csv(csv_path)
    print(f"✅ Loaded {len(df)} annotations from {csv_path.name}")
    return df

def visualize_annotations_for_image(image_file: str, df: pd.DataFrame):
    annotations = df[df["image_file_name"] == image_file]
    if annotations.empty:
        print(f"⚠️  No annotations for {image_file}, skipping.")
        return

    img_path = STILLS_FOLDER / image_file
    if not img_path.exists():
        print(f"❌ Still image not found: {img_path}")
        return

    # Load image
    img = cv2.imread(str(img_path))
    if img is None:
        print(f"❌ Could not load image: {img_path}")
        return

    # Draw each annotation
    for _, row in annotations.iterrows():
        x1, y1 = int(row["x_min"]), int(row["y_min"])
        x2, y2 = int(row["x_max"]), int(row["y_max"])
        label   = str(row["object_name"])

        # Bounding box
        cv2.rectangle(img, (x1, y1), (x2, y2), BOX_COLOR, BOX_THICKNESS)

        # Center dot
        cx, cy = (x1 + x2) // 2, (y1 + y2) // 2
        cv2.circle(img, (cx, cy), CENTER_DOT_RADIUS, CENTER_DOT_COLOR, -1)

        # Label background
        (w, h), _ = cv2.getTextSize(label, FONT_FACE, FONT_SCALE, 1)
        cv2.rectangle(img, (x1, y1 - h - 4), (x1 + w, y1), BOX_COLOR, -1)

        # Label text
        cv2.putText(img, label, (x1, y1 - 2), FONT_FACE, FONT_SCALE, TEXT_COLOR, 1, cv2.LINE_AA)

    # Save the visualization
    out_path = OUTPUT_FOLDER / f"{Path(image_file).stem}_visualized.jpg"
    out_path.parent.mkdir(parents=True, exist_ok=True)
    cv2.imwrite(str(out_path), img)
    print(f"✅ Saved visualization: {out_path.name}")

def main():
    mount_drive()
    df = load_annotations(INPUT_CSV)
    if df is None:
        return

    # Make sure output folder exists
    OUTPUT_FOLDER.mkdir(parents=True, exist_ok=True)

    # Iterate over every unique still in the annotations
    for image_file in df["image_file_name"].unique():
        visualize_annotations_for_image(image_file, df)

    print("\n🎉 All stills processed!")

if __name__ == "__main__":
    main()
# Out:
# 🔗 Mounting Google Drive…
# Mounted at /content/drive
# ✅ Drive mounted.
# ✅ Loaded 888 annotations from final_annotations.csv
# ✅ Saved visualization: 1086533-hd_1280_720_25fps_0001_visualized.jpg
# ✅ Saved visualization: 1197801-hd_1920_1080_25fps_0001_visualized.jpg
# ✅ Saved visualization: 1197801-hd_1920_1080_25fps_0004_visualized.jpg
# ✅ Saved visualization: 1197802-hd_1920_1080_25fps_0001_visualized.jpg
# ✅ Saved visualization: 1322056-hd_1920_1080_30fps_0001_visualized.jpg
# ✅ Saved visualization: 13856488_3840_2160_60fps_0001_visualized.jpg
# ✅ Saved visualization: 1509518-uhd_3840_2160_30fps_0001_visualized.jpg
# ✅ Saved visualization: 1562544-sd_568_320_30fps_0001_visualized.jpg
# ✅ Saved visualization: 1580509-hd_1920_1080_30fps_0001_visualized.jpg
# ✅ Saved visualization: 2103099-uhd_3840_2160_30fps_0001_visualized.jpg
# ✅ Saved visualization: 2281947-hd_1920_1080_25fps_0007_visualized.jpg
# ✅ Saved visualization: 2281947-hd_1920_1080_25fps_0025_visualized.jpg
# ✅ Saved visualization: 2317680-uhd_3840_2160_24fps_0001_visualized.jpg
# ✅ Saved visualization: 243647_small_0001_visualized.jpg
# ✅ Saved visualization: 2464034-hd_1920_1080_30fps_0022_visualized.jpg
# ✅ Saved visualization: 253998_small_0001_visualized.jpg
# ✅ Saved visualization: 2565594-hd_1280_720_24fps_0001_visualized.jpg
# ✅ Saved visualization: 2565594-hd_1280_720_24fps_0004_visualized.jpg
# ✅ Saved visualization: 2565594-hd_1280_720_24fps_0010_visualized.jpg
# ✅ Saved visualization: 2565594-hd_1280_720_24fps_0019_visualized.jpg
# ✅ Saved visualization: 2565594-hd_1280_720_24fps_0022_visualized.jpg
# ✅ Saved visualization: 2565594-hd_1280_720_24fps_0034_visualized.jpg
# ✅ Saved visualization: 2565594-hd_1280_720_24fps_0043_visualized.jpg
# ✅ Saved visualization: 2565594-hd_1280_720_24fps_0049_visualized.jpg
# ✅ Saved visualization: 265501_small_0025_visualized.jpg
# ✅ Saved visualization: 275498_small_0013_visualized.jpg
# ✅ Saved visualization: 2795165-uhd_3840_2160_25fps_0001_visualized.jpg
# ✅ Saved visualization: 2795309-uhd_3840_2160_25fps_0007_visualized.jpg
# ✅ Saved visualization: 2835528-hd_1920_1080_25fps_0001_visualized.jpg
# ✅ Saved visualization: 2932301-uhd_4096_2160_24fps_0004_visualized.jpg
# ✅ Saved visualization: 2932301-uhd_4096_2160_24fps_0007_visualized.jpg
# ✅ Saved visualization: 3006961-hd_1920_1080_24fps_0001_visualized.jpg
# ✅ Saved visualization: 3014986-hd_1920_1080_30fps_0004_visualized.jpg
# ✅ Saved visualization: 3014986-hd_1920_1080_30fps_0016_visualized.jpg
# ✅ Saved visualization: 3014986-hd_1920_1080_30fps_0116_visualized.jpg
# ✅ Saved visualization: 3014986-hd_1920_1080_30fps_0122_visualized.jpg
# ✅ Saved visualization: 3014986-hd_1920_1080_30fps_0125_visualized.jpg
uhd_3840_2160_25fps_0001_visualized.jpg
# ✅ Saved visualization: 5699643-uhd_3840_2160_24fps_0013_visualized.jpg
# ✅ Saved visualization: 5734826-hd_1920_1080_30fps_0010_visualized.jpg
# ✅ Saved visualization: 5928085-hd_1920_1080_30fps_0004_visualized.jpg
# ✅ Saved visualization: 5928085-hd_1920_1080_30fps_0007_visualized.jpg
# ✅ Saved visualization: 6109190-hd_1920_1080_30fps_0001_visualized.jpg
# ✅ Saved visualization: 6109190-hd_1920_1080_30fps_0004_visualized.jpg
# ✅ Saved visualization: 6109190-hd_1920_1080_30fps_0007_visualized.jpg
# ✅ Saved visualization: 6406174-hd_1920_1080_25fps_0025_visualized.jpg
# ✅ Saved visualization: 6613922-hd_1920_1080_25fps_0004_visualized.jpg
# ✅ Saved visualization: 6633115-hd_1920_1080_25fps_0007_visualized.jpg
# ✅ Saved visualization: 6893843-uhd_3840_2160_25fps_0001_visualized.jpg
# ✅ Saved visualization: 6893843-uhd_3840_2160_25fps_0016_visualized.jpg
# ✅ Saved visualization: 6951348-hd_1920_1080_25fps_0001_visualized.jpg
# ✅ Saved visualization: 6994693-uhd_3840_2160_30fps_0001_visualized.jpg
# ✅ Saved visualization: 7579952-uhd_4096_2160_25fps_0001_visualized.jpg
# ✅ Saved visualization: 7669058-uhd_3840_2160_25fps_0001_visualized.jpg
# ✅ Saved visualization: 7821640-hd_1920_1080_30fps_0004_visualized.jpg
# ✅ Saved visualization: 8467625-uhd_4096_2160_25fps_0007_visualized.jpg
# ✅ Saved visualization: 8468767-uhd_4096_2160_25fps_0001_visualized.jpg
# ✅ Saved visualization: 8499667-hd_1920_1080_30fps_0001_visualized.jpg
# ✅ Saved visualization: 852038-hd_1920_1080_30fps_0007_visualized.jpg
# ✅ Saved visualization: 852038-hd_1920_1080_30fps_0022_visualized.jpg
# ✅ Saved visualization: 852122-hd_1920_1080_30fps_0031_visualized.jpg
# ✅ Saved visualization: 852424-hd_1920_1080_24fps_0007_visualized.jpg
# ✅ Saved visualization: 853797-hd_1920_1080_25fps_0004_visualized.jpg
# ✅ Saved visualization: 853878-hd_1920_1080_25fps_0010_visualized.jpg
# ✅ Saved visualization: 854022-hd_1920_1080_25fps_0013_visualized.jpg
# ✅ Saved visualization: 854069-hd_1920_1080_25fps_0001_visualized.jpg
# ✅ Saved visualization: 854118-hd_1920_1080_25fps_0001_visualized.jpg
# ✅ Saved visualization: 854123-hd_1920_1080_25fps_0001_visualized.jpg
# ✅ Saved visualization: 854123-hd_1920_1080_25fps_0019_visualized.jpg
# ✅ Saved visualization: 855237-hd_1920_1080_25fps_0001_visualized.jpg
# ✅ Saved visualization: 856132-hd_1920_1080_30fps_0001_visualized.jpg
# ✅ Saved visualization: 8852604-hd_1920_1080_30fps_0001_visualized.jpg
# ✅ Saved visualization: 946147-hd_1920_1080_30fps_0001_visualized.jpg
# ✅ Saved visualization: 992606-hd_1920_1080_25fps_0001_visualized.jpg
# ✅ Saved visualization: Alloys Commitment to Support and Results_0001_visualized.jpg
# ✅ Saved visualization: Alloys Commitment to Support and Results_0005_visualized.jpg
# ✅ Saved visualization: Alloys Commitment to Support and Results_0009_visualized.jpg
# ✅ Saved visualization: Choice 1 Personal Training Foundations_0001_visualized.jpg
# ✅ Saved visualization: Choice 1 Personal Training Foundations_0009_visualized.jpg
# ✅ Saved visualization: Choice 2 Small Group Classes_0001_visualized.jpg
# ✅ Saved visualization: Choice 2 Small Group Classes_0005_visualized.jpg
# ✅ Saved visualization: Customizing Your Training Experience_0001_visualized.jpg
# ✅ Saved visualization: Customizing Your Training Experience_0005_visualized.jpg
# ✅ Saved visualization: Path 1 Get Started with Fitness_0001_visualized.jpg
# ✅ Saved visualization: Path 1 Get Started with Fitness_0009_visualized.jpg
# ✅ Saved visualization: Path 2 Build Strength and Endurance_0001_visualized.jpg
# ✅ Saved visualization: Path 2 Build Strength and Endurance_0005_visualized.jpg
# ✅ Saved visualization: Path 2 Choice 1 Strength Focused Personal Training_0001_visualized.jpg
# ✅ Saved visualization: Path 2 Choice 1 Strength Focused Personal Training_0005_visualized.jpg
# ✅ Saved visualization: Path 2 Choice 1 Strength Focused Personal Training_0009_visualized.jpg
# ✅ Saved visualization: Path 2 Choice 2 Specialized Group Training Session_0001_visualized.jpg
# ✅ Saved visualization: Path 2 Choice 2 Specialized Group Training Session_0009_visualized.jpg
# ✅ Saved visualization: Path 2 Choice 2 Specialized Group Training Session_0013_visualized.jpg
# ✅ Saved visualization: Path 3 Choice 1 Personalized Weight Loss Coaching_0001_visualized.jpg
# ✅ Saved visualization: Path 3 Choice 1 Personalized Weight Loss Coaching_0009_visualized.jpg
# ✅ Saved visualization: Path 3 Choice 2 Metabolic Conditioning Group Classes_0001_visualized.jpg
# ✅ Saved visualization: Path 3 Choice 2 Metabolic Conditioning Group Classes_0009_visualized.jpg
# ✅ Saved visualization: Path 3 Focus on Weight Loss and Wellness_0001_visualized.jpg
# ✅ Saved visualization: Path 3 Focus on Weight Loss and Wellness_0005_visualized.jpg
# ✅ Saved visualization: Path 4 Choice 1 Workout Frequency and Scheduling_0001_visualized.jpg
# ✅ Saved visualization: Path 4 Choice 1 Workout Frequency and Scheduling_0009_visualized.jpg
# ✅ Saved visualization: Path 4 Choice 2 Intensity Preferences_0001_visualized.jpg
# ✅ Saved visualization: Path 4 Choice 2 Intensity Preferences_0005_visualized.jpg
# ✅ Saved visualization: Path 4 Choice 3 Specific Areas of Focus_0001_visualized.jpg
# ✅ Saved visualization: Path 4 Choice 3 Specific Areas of Focus_0009_visualized.jpg
# ✅ Saved visualization: Path 5 Choice 1 Meet Your Trainers_0001_visualized.jpg
# ✅ Saved visualization: Path 5 Choice 1 Meet Your Trainers_0005_visualized.jpg
# ✅ Saved visualization: Path 5 Choice 2 Understand Our Accountability System_0001_visualized.jpg
# ✅ Saved visualization: Path 5 Choice 2 Understand Our Accountability System_0009_visualized.jpg
# ✅ Saved visualization: Schedule a Free Consultation_0001_visualized.jpg
# ✅ Saved visualization: Schedule a Free Consultation_0005_visualized.jpg
# ✅ Saved visualization: Welcome to Alloy Personal Training_0005_visualized.jpg
# ✅ Saved visualization: Welcome to Alloy Personal Training_0009_visualized.jpg
#
# 🎉 All stills processed!
